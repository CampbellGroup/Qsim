# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path = '/home/qsim-rad/LabRAD/Data/PMT_FFT.dir/'

# %%
fft320 = np.loadtxt(path + '00301 - PMT_FFT.csv', delimiter = ',')
fft321 = np.loadtxt(path + '00302 - PMT_FFT.csv', delimiter = ',')

# %%
freq320, y320 = fft320[:,0], fft320[:,1]
freq321, y321 = fft321[:,0], fft321[:,1]

# %%
plt.plot(freq320, y320)
plt.plot(freq321, y321)
