# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/PMT Counts.dir/01235 - PMT Counts.csv',delimiter=',')

# %%
plt.plot(np.array(data[52300:55340,0])/10.0, data[52300:55340,1])
plt.title('6 ion crystal hopping')
plt.xlabel('time, (s)')
plt.ylabel('Fluorescence (kcts/sec)')
plt.savefig('/home/qsimexpcontrol/plots/6_ion_metastable/27JUN2017hopping_pmt.pdf')
# Out:
# <img src="data:image/png;base64,..." width="940.0000249014967">

# %%
tmpx = data[29150:30680,0]
tmpy = data[29150:30680,1]

f = open("/home/qsimexpcontrol/plots/6_ion_metastable/26JUN2017hopping_pmt.csv", "w")

for i in xrange(len(tmpx)):
    f.write("{} {}\n".format(tmpx[i], tmpy[i]))
