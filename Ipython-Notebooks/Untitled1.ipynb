# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
x = [0.138, 0.133, 0.125, 0.118, 0.108,
0.147, 0.151, 0.159]
y = [1.338, 1, 0.5, 0.25, 0.1, 2, 2.25, 2.5]

# %%
plt.scatter(x,y)
# Out:
# <img src="data:image/png;base64,...">
