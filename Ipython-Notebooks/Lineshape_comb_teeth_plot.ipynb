# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %pylab inline
pylab.rcParams['figure.figsize'] = (12,8)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def lorentzian(detuning, gamma):
    return (gamma/2)/(detuning**2 + (gamma/2)**2)

x = np.linspace(-120,120,100)

# %%
plt.plot(x,15*lorentzian(x,20),'b', label='Atomic Lineshape', lw = 4)
plt.plot(x,lorentzian(x + 110, 0.2) + lorentzian(x + 30, 0.2)\
         + lorentzian(x - 50, 0.2), 'black', label='Comb Teeth', lw = 4)
plt.arrow(-100, 0.8, 60, 0.0, head_width=0.06, head_length= 8, fc='r', ec='r' )
plt.arrow(-40, 0.8, -60, 0.0, head_width=0.06, head_length= 8, fc='r', ec='r' )
plt.arrow(60, 0.8, 20, 0.0, head_width =0.06, head_length = 8, fc = 'g', ec = 'g')
plt.xlabel('Detuning [MHz]', fontsize = 22)
plt.ylabel('Intensity [arb.u]', fontsize = 22)
plt.title('Mode locked laser comb teeth on atomic spectrum', fontsize = 25)
plt.text(-100.0, 0.9, r'$f_{rep} \approx 80$ MHz', fontsize = 15)
plt.text(70.0, 0.9, r'PZT scan', fontsize = 15)
plt.legend(loc=1, fontsize = 15)
plt.show()
