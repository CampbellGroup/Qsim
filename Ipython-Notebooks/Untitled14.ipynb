# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.style.use('crizzle')

# %%
path = '/home/qsim-rad/LabRAD/data/ML_decoherence.dir/'

data = np.loadtxt(path + '00012 - ML_decoherence.csv', delimiter=',')
t = data[:,0]
bright = data[:,1]
dark = data[:,2]
diff = data[:,3]

# %%
fig, ax = plt.subplots(figsize=(12,8))
plt.plot(t, bright, label='Bright State Prepared')
plt.plot(t, dark, label='Dark State Prepared')
#plt.plot(t, diff, label='Fidelity')
plt.xlabel(r'ML Interrogation Time [$\mu$s]', fontsize = 25)
plt.ylabel(r'$P_{ex}$', fontsize=25)
plt.legend()

plt.savefig(path + 'ML_decoherence_first_attempt.pdf')
