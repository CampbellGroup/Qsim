# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('/home/qsimexpcontrol/LabRAD/data/metastable_transition.dir/00087 - metastable_transition.dir/images.npy')

# %%
image_list = []
for i, item in enumerate(data):
    if i == 2:
        data_resize = item.reshape(1002,1004)
        image_list.append(data_resize)

# %%
for image in image_list:
    #fig = plt.figure()
    #ax = fig.add_subplot(111)
    plt.imshow(image, clim=[300, 400], cmap='gray')
# Out:
# <img src="data:image/png;base64,..." width="640">
