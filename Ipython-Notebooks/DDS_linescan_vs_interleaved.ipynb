# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
interleaved = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/InterleavedLinescan.dir/00603 - InterleavedLinescan.csv'
                         ,delimiter=',')
DDS = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/DDS_LineScan.dir/00658 - DDS_LineScan.csv',delimiter=',')

# %%
plt.plot(interleaved[:,0] - 2.0, 1.6*interleaved[:,1]/1000 - 6.0)
plt.plot(DDS[:,0]- 2.0, DDS[:,1] - 1.9)
plt.title('Interleaved vs Laser Sweep')
plt.xlabel('detuning [MHz]')
plt.ylabel('scatter rate [kHz]')
plt.savefig('/home/qsimexpcontrol/plots/ML_Laser/30MAY2017DDS_vs_interleaved.pdf')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
