# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
center_pll = 12.6428041e9
DDS_source_wide = np.loadtxt('/home/qsimexpcontrol/plots/DDS_Noise/Trace_0011_data.csv',delimiter=',')
DDS_source_narrow = np.loadtxt('/home/qsimexpcontrol/plots/DDS_Noise/Trace_0012_data.csv',delimiter=',')

# %%
plt.figure()
plt.plot((DDS_source_wide[:,0]-center_pll)/1000., DDS_source_wide[:,1], 'purple')
plt.xlabel('Frequency(kHz)')
plt.ylabel('Power (dbm)')
#plt.savefig("/home/qsimexpcontrol/plots/DAC_Noise/before_afterextfilter.pdf")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot((DDS_source_narrow[:,0] - center_pll)/1000., DDS_source_narrow[:,1], 'darkorange')
plt.xlabel('Frequency(kHz)')
plt.ylabel('Power (dbm)')
#plt.savefig("/home/qsimexpcontrol/plots/DAC_Noise/before_afterextfilter.pdf")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
center_dds = 93.6504*1e6
DDS_only_wide = np.loadtxt('/home/qsimexpcontrol/plots/DDS_Noise/Trace_0013_data.csv',delimiter=',')
DDS_only_narrow = np.loadtxt('/home/qsimexpcontrol/plots/DDS_Noise/Trace_0014_data.csv',delimiter=',')
magiQ_only_wide = np.loadtxt('/home/qsimexpcontrol/plots/DDS_Noise/Trace_0016_data.csv',delimiter=',')
magiQ_only_narrow = np.loadtxt('/home/qsimexpcontrol/plots/DDS_Noise/Trace_0015_data.csv',delimiter=',')

# %%
plt.figure()
plt.plot((DDS_only_wide[:,0]-center_dds)/1000., DDS_only_wide[:,1], 'purple')
plt.xlabel('Frequency(kHz)')
plt.ylabel('Power (dbm)')
#plt.savefig("/home/qsimexpcontrol/plots/DAC_Noise/before_afterextfilter.pdf")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot((DDS_only_narrow[:,0]-center_dds)/1000., DDS_only_narrow[:,1], 'purple')
plt.xlabel('Frequency(kHz)')
plt.ylabel('Power (dbm)')
#plt.savefig("/home/qsimexpcontrol/plots/DAC_Noise/before_afterextfilter.pdf")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
