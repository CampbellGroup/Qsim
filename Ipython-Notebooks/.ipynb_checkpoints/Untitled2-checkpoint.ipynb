# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
temp = np.loadtxt('/home/qsimexpcontrol/LabRAD/common/lib/clients/temperature_monitor/all_time_temp.csv', delimiter=' ')

# %%
len(temp)
# Out:
# 2

# %%
times = (temp[0] - 1406403721)/3e7
temps = temp[1]
plt.plot(times,temps)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
freqs = np.linspace(1e-7,0.1, 500)
mat = np.exp(-1.j * 2.0 * np.pi * np.outer(freqs, times))
fft = mat.sum(axis=1)
pwr = np.abs(fft) ** 2.0

# %%
plt.plot(freqs, pwr)

# %%
from scipy.fftpack import fft

yf = fft(temps)
print len(temps)
mins = 1000000
yf = np.fft.fft(temps[-mins:-1])
# Out:
# 1521296

# %%
# %matplotlib notebook

fig = plt.figure()
ax = fig.add_subplot(211)
ax2 = fig.add_subplot(212)
#ax.plot(time, temps)
df = 1./mins
ax2.plot(np.linspace(0, len(abs(yf))*df, len(abs(yf))), np.abs(yf))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
(1./4.8e-5)/1440
# Out:
# 14.467592592592592

# %%
60*24
# Out:
# 1440

# %%
np.linspace(0, len(abs(yf))*df, len(abs(yf)))
# Out:
# array([  0.00000000e+00,   1.00000100e-06,   2.00000200e-06, ...,
#          9.99997000e-01,   9.99998000e-01,   9.99999000e-01])
