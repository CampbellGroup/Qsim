# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
MLpiezo106 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00106 - MLpiezoscan.csv',delimiter=',')
MLpiezo107 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00107 - MLpiezoscan.csv',delimiter=',')
MLpiezo108 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00106 - MLpiezoscan.csv',delimiter=',')
MLpiezo109 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00107 - MLpiezoscan.csv',delimiter=',')
MLpiezo110 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00106 - MLpiezoscan.csv',delimiter=',')
MLpiezo111 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00107 - MLpiezoscan.csv',delimiter=',')
MLpiezo112 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00106 - MLpiezoscan.csv',delimiter=',')
MLpiezo113 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00107 - MLpiezoscan.csv',delimiter=',')
MLpiezo114 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00106 - MLpiezoscan.csv',delimiter=',')
MLpiezo115 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00107 - MLpiezoscan.csv',delimiter=',')

# %%
MLpiezo117 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00117 - MLpiezoscan.csv',delimiter=',')
MLpiezo118 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00118 - MLpiezoscan.csv',delimiter=',')
MLpiezo119 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00119 - MLpiezoscan.csv',delimiter=',')
MLpiezo120 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00120 - MLpiezoscan.csv',delimiter=',')
MLpiezo121 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00121 - MLpiezoscan.csv',delimiter=',')
MLpiezo122 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00122 - MLpiezoscan.csv',delimiter=',')
MLpiezo123 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00123 - MLpiezoscan.csv',delimiter=',')
MLpiezo124 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00124 - MLpiezoscan.csv',delimiter=',')
MLpiezo125 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00125 - MLpiezoscan.csv',delimiter=',')
MLpiezo126 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00126 - MLpiezoscan.csv',delimiter=',')

# %%
mean_low = (MLpiezo117[:,1] + MLpiezo118[:,1] + MLpiezo119[:,1] + MLpiezo120[:,1] + MLpiezo121[:,1] \
        + MLpiezo122[:,1] + MLpiezo123[:,1] + MLpiezo124[:,1] + MLpiezo125[:,1] +MLpiezo126[:,1])/10.0
plt.xlabel('ML Piezo (volts)')
plt.ylabel('Intensity (kcounts/sec)')
plt.plot(volts - 0.5, mean_low, label = '-13 dBm')
plt.plot(volts + 0.5, mean_high, label = '-12 dBm')
plt.legend()
# Out:
# <img src="data:image/png;base64,...">

# %%
pmtdata = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/PMT Counts.dir/01150 - PMT Counts.csv',delimiter=',')

# %%
def coursen(xdata,ydata,points):
    newlength = int(len(xdata)/points)
    newxdata = []
    newydata = []
    j = 0
    for i in range(newlength):
        i = points*(i)
        newydata.append(np.mean(ydata[int(j):int(i)]))
        newxdata.append(xdata[int((i + j)/2)])
        j = i
    return newxdata, newydata

# %%
time = pmtdata[12150:30500][:,0]
counts = pmtdata[12150:30500][:,3]
coursedx, coursedy = coursen(np.array(time - time[0]),np.array(counts), 200)
plt.title('Ion lifetime ML laser only')
plt.xlabel('Time (s)')
plt.ylabel('Intensity (kCounts/second)')
plt.plot(coursedx, coursedy, color='g', linewidth=2)
#plt.savefig('/home/qsimexpcontrol/plots/ML_Laser/8MAY2017ML_only_lifetime.png')
# Out:
# <img src="data:image/png;base64,...">

# %%
MLpiezo216 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00106 - MLpiezoscan.csv',delimiter=',')
MLpiezo = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00107 - MLpiezoscan.csv',delimiter=',')
MLpiezo108 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00106 - MLpiezoscan.csv',delimiter=',')
MLpiezo109 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00107 - MLpiezoscan.csv',delimiter=',')
MLpiezo110 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00106 - MLpiezoscan.csv',delimiter=',')
MLpiezo111 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00107 - MLpiezoscan.csv',delimiter=',')
MLpiezo112 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00106 - MLpiezoscan.csv',delimiter=',')
MLpiezo113 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00107 - MLpiezoscan.csv',delimiter=',')
MLpiezo114 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00106 - MLpiezoscan.csv',delimiter=',')
MLpiezo115 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00107 - MLpiezoscan.csv',delimiter=',')
