# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
# Out:
# /home/qsimexpcontrol/.virtualenvs/labrad/local/lib/python2.7/site-packages/matplotlib/__init__.py:1035: UserWarning: Duplicate key in file "/home/qsimexpcontrol/.virtualenvs/labrad/local/lib/python2.7/site-packages/matplotlib/mpl-data/matplotlibrc", line #512
#   (fname, cnt))

# %%
def data_average(preamble, experiment, datasets):
    for i, item in enumerate(data_sets):
        temp = np.loadtxt(preamble + experiment)

# %%
MLpiezo275 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00275 - MLpiezoscan.csv',delimiter=',')
MLpiezo276 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00276 - MLpiezoscan.csv',delimiter=',')
MLpiezo277 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00277 - MLpiezoscan.csv',delimiter=',')
MLpiezo278 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00278 - MLpiezoscan.csv',delimiter=',')
MLpiezo279 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00279 - MLpiezoscan.csv',delimiter=',')
MLpiezo280 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00280 - MLpiezoscan.csv',delimiter=',')
MLpiezo281 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00281 - MLpiezoscan.csv',delimiter=',')
MLpiezo282 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00282 - MLpiezoscan.csv',delimiter=',')
MLpiezo283 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00283 - MLpiezoscan.csv',delimiter=',')
MLpiezo284 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00284 - MLpiezoscan.csv',delimiter=',')
MLpiezo285 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00285 - MLpiezoscan.csv',delimiter=',')
MLpiezo286 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00286 - MLpiezoscan.csv',delimiter=',')
MLpiezo287 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00287 - MLpiezoscan.csv',delimiter=',')
MLpiezo288 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00288 - MLpiezoscan.csv',delimiter=',')
MLpiezo289 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00289 - MLpiezoscan.csv',delimiter=',')
MLpiezo290 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00290 - MLpiezoscan.csv',delimiter=',')
MLpiezo291 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00291 - MLpiezoscan.csv',delimiter=',')
MLpiezo292 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00292 - MLpiezoscan.csv',delimiter=',')
MLpiezo293 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00293 - MLpiezoscan.csv',delimiter=',')
MLpiezo294 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00294 - MLpiezoscan.csv',delimiter=',')

# %%
MLpiezo296 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00296 - MLpiezoscan.csv',delimiter=',')
MLpiezo297 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00297 - MLpiezoscan.csv',delimiter=',')
MLpiezo298 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00298 - MLpiezoscan.csv',delimiter=',')
MLpiezo299 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00299 - MLpiezoscan.csv',delimiter=',')
MLpiezo300 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00300 - MLpiezoscan.csv',delimiter=',')
MLpiezo301 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00301 - MLpiezoscan.csv',delimiter=',')
MLpiezo302 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00302 - MLpiezoscan.csv',delimiter=',')
MLpiezo303 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00303 - MLpiezoscan.csv',delimiter=',')
MLpiezo304 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00304 - MLpiezoscan.csv',delimiter=',')
MLpiezo305 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00305 - MLpiezoscan.csv',delimiter=',')
MLpiezo306 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00306 - MLpiezoscan.csv',delimiter=',')
MLpiezo307 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00307 - MLpiezoscan.csv',delimiter=',')
MLpiezo308 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00308 - MLpiezoscan.csv',delimiter=',')
MLpiezo309 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00309 - MLpiezoscan.csv',delimiter=',')
MLpiezo310 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00310 - MLpiezoscan.csv',delimiter=',')
MLpiezo311 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00311 - MLpiezoscan.csv',delimiter=',')
MLpiezo312 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00312 - MLpiezoscan.csv',delimiter=',')
MLpiezo313 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00313 - MLpiezoscan.csv',delimiter=',')
MLpiezo314 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00314 - MLpiezoscan.csv',delimiter=',')
MLpiezo315 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00315 - MLpiezoscan.csv',delimiter=',')

# %%
MLpiezo316 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00316 - MLpiezoscan.csv',delimiter=',')
MLpiezo317 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00317 - MLpiezoscan.csv',delimiter=',')
MLpiezo318 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00318 - MLpiezoscan.csv',delimiter=',')
MLpiezo319 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00319 - MLpiezoscan.csv',delimiter=',')
MLpiezo320 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00320 - MLpiezoscan.csv',delimiter=',')
MLpiezo321 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00321 - MLpiezoscan.csv',delimiter=',')
MLpiezo322 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00322 - MLpiezoscan.csv',delimiter=',')
MLpiezo323 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00323 - MLpiezoscan.csv',delimiter=',')
MLpiezo324 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00324 - MLpiezoscan.csv',delimiter=',')
MLpiezo325 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00325 - MLpiezoscan.csv',delimiter=',')
MLpiezo326 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00326 - MLpiezoscan.csv',delimiter=',')
MLpiezo327 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00327 - MLpiezoscan.csv',delimiter=',')
MLpiezo328 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00328 - MLpiezoscan.csv',delimiter=',')
MLpiezo329 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00329 - MLpiezoscan.csv',delimiter=',')
MLpiezo330 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00330 - MLpiezoscan.csv',delimiter=',')
MLpiezo331 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00331 - MLpiezoscan.csv',delimiter=',')
MLpiezo332 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00332 - MLpiezoscan.csv',delimiter=',')
MLpiezo333 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00333 - MLpiezoscan.csv',delimiter=',')
MLpiezo334 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00334 - MLpiezoscan.csv',delimiter=',')
MLpiezo335 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00335 - MLpiezoscan.csv',delimiter=',')

# %%
CWMLpiezo336 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00336 - MLpiezoscan.csv',delimiter=',')
MLpiezo337 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00337 - MLpiezoscan.csv',delimiter=',')
MLpiezo338 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00338 - MLpiezoscan.csv',delimiter=',')
MLpiezo339 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00339 - MLpiezoscan.csv',delimiter=',')
MLpiezo340 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00340 - MLpiezoscan.csv',delimiter=',')
MLpiezo341 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00341 - MLpiezoscan.csv',delimiter=',')
MLpiezo342 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00342 - MLpiezoscan.csv',delimiter=',')
MLpiezo343 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00343 - MLpiezoscan.csv',delimiter=',')
MLpiezo344 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00344 - MLpiezoscan.csv',delimiter=',')
MLpiezo345 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00345 - MLpiezoscan.csv',delimiter=',')
MLpiezo346 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00346 - MLpiezoscan.csv',delimiter=',')
MLpiezo347 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00347 - MLpiezoscan.csv',delimiter=',')
MLpiezo348 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00348 - MLpiezoscan.csv',delimiter=',')
MLpiezo349 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00349 - MLpiezoscan.csv',delimiter=',')
MLpiezo350 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00350 - MLpiezoscan.csv',delimiter=',')
MLpiezo351 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00351 - MLpiezoscan.csv',delimiter=',')
MLpiezo352 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00352 - MLpiezoscan.csv',delimiter=',')
MLpiezo353 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00353 - MLpiezoscan.csv',delimiter=',')
MLpiezo354 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00354 - MLpiezoscan.csv',delimiter=',')
MLpiezo355 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00355 - MLpiezoscan.csv',delimiter=',')

# %%
volts = MLpiezo275[:,0]
mean_minus_12 = (MLpiezo275[:,1] + MLpiezo276[:,1] + MLpiezo277[:,1] + MLpiezo278[:,1] + MLpiezo279[:,1] \
        + MLpiezo280[:,1] + MLpiezo281[:,1] + MLpiezo282[:,1] + MLpiezo283[:,1] + MLpiezo284[:,1] \
        + MLpiezo285[:,1] + MLpiezo286[:,1] + MLpiezo287[:,1] + MLpiezo288[:,1] + MLpiezo289[:,1] \
        + MLpiezo290[:,1] + MLpiezo291[:,1] + MLpiezo292[:,1] + MLpiezo293[:,1] + MLpiezo294[:,1])/20
mean_minus_10 = (MLpiezo311[:,1] + MLpiezo312[:,1] + MLpiezo313[:,1] + MLpiezo314[:,1] + MLpiezo315[:,1] \
        + MLpiezo296[:,1] + MLpiezo297[:,1] + MLpiezo298[:,1] + MLpiezo299[:,1] + MLpiezo300[:,1] \
        + MLpiezo301[:,1] + MLpiezo302[:,1] + MLpiezo303[:,1] + MLpiezo304[:,1] + MLpiezo305[:,1] \
        + MLpiezo306[:,1] + MLpiezo307[:,1] + MLpiezo308[:,1] + MLpiezo309[:,1] + MLpiezo310[:,1])/20
mean_minus_8 = (MLpiezo316[:,1] + MLpiezo317[:,1] + MLpiezo318[:,1] + MLpiezo319[:,1] + MLpiezo320[:,1] \
        + MLpiezo321[:,1] + MLpiezo322[:,1] + MLpiezo323[:,1] + MLpiezo324[:,1] + MLpiezo325[:,1] \
        + MLpiezo326[:,1] + MLpiezo327[:,1] + MLpiezo328[:,1] + MLpiezo329[:,1] + MLpiezo330[:,1] \
        + MLpiezo331[:,1] + MLpiezo332[:,1] + MLpiezo333[:,1] + MLpiezo334[:,1] + MLpiezo335[:,1])/20
mean_minus_14 = (MLpiezo336[:,1] + MLpiezo337[:,1] + MLpiezo338[:,1] + MLpiezo339[:,1] + MLpiezo340[:,1] \
        + MLpiezo341[:,1] + MLpiezo342[:,1] + MLpiezo343[:,1] + MLpiezo344[:,1] + MLpiezo345[:,1] \
        + MLpiezo346[:,1] + MLpiezo347[:,1] + MLpiezo348[:,1] + MLpiezo349[:,1] + MLpiezo350[:,1] \
        + MLpiezo351[:,1] + MLpiezo352[:,1] + MLpiezo353[:,1] + MLpiezo354[:,1] + MLpiezo355[:,1])/20

# %%
plt.plot(volts -0.9, mean_minus_14, label='-14 dBm', linewidth=2)
plt.plot(volts, mean_minus_12, label='-12 dBm', linewidth=2)
plt.plot(volts-0.3, mean_minus_10, label='-10 dBm', linewidth=2)
plt.plot(volts -0.6, mean_minus_8, label='-8 dBm', linewidth=2)
plt.xlabel('Mode-locked cavity piezo voltage')
plt.ylabel('Fluorescense (kcounts/s)')
plt.title('Mode-Locked scanned 34 MHz detuned CW 369 at different powers')
plt.legend(loc=3)
# Out:
# <img src="data:image/png;base64,...">
