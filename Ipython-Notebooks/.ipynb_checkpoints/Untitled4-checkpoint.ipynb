# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
pmtData = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/PMT Counts.dir/01431 - PMT Counts.csv',delimiter = ',')

# %%
time, countsNorm, countsScatt, countsDiff = pmtData[:,0], pmtData[:,1], pmtData[:,2], pmtData[:,3]
print len(countsNorm)
# Out:
# 682105

# %%
#plt.plot(time[60000:125000], countsNorm[60000:125000], 'purple')
plt.plot(time[60000:125000], countsScatt[60000:125000], 'green')
plt.plot(time[60000:125000], countsDiff[60000:125000], 'blue')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
