# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
def data_average(preamble, experiment, datasets):
    for i, item in enumerate(datasets):
        item = str(item)
        if len(item) < 5:
            item = (5 -len(item))*'0' + item
        temp = np.loadtxt(preamble + item  + ' - ' + experiment + '.csv', delimiter=',')
        if i != 0:
            prev_y = temp[:,1] + prev_y
        else:
            x_values = temp[:,0] + 1
            prev_y = temp[:,1]
    y_values = prev_y/len(datasets)
    return [x_values, y_values]

# %% [markdown]
# ## Taken with 20 pics CW on 920 $\mu W$

# %%
x, y = data_average('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/', 'MLpiezoscan', range(438,447))
images = np.load('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00438 - MLpiezoscan.npy')
image_list = []
for item in images:
    data_resize = item.reshape(301, 301)
    image_list.append(data_resize)
fig = plt.figure(figsize=(16, 16))
ax1 = plt.subplot2grid((2, 10), (0, 0), colspan=10)
ax1.plot(x[10:], y[10:])   
#plt.figure(figsize=(4, 5)
#fig = plt.figure(figsize=(20,30))
for i, image in enumerate(image_list):
    ax = plt.subplot2grid((2,10),(1, i))
    ax.set_axis_off()
    ax.imshow(image, clim=[100, 1600], cmap='gray')
plt.subplots_adjust(wspace=0, hspace=0)

# %% [markdown]
# ## No pics CW on ML power ~ 70 $\mu W$

# %%
x, y = data_average('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/', 'MLpiezoscan', range(419,430))
plt.plot(x,y)Modulation_depth_vs_distance
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import matplotlib as mpl
x, y = data_average('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/', 'MLpiezoscan', range(503,508))
images = np.load('/home/qsimexpcontrol/LabRAD/data/MLpiezoscan.dir/00503 - MLpiezoscan.npy')
image_list = [] 
for item in images:
    data_resize = item.reshape(301, 301)
    image_list.append(data_resize)
fig = plt.figure()#figsize=(16, 16))
ax1 = plt.subplot2grid((2, 10), (0, 0), colspan=10)
ax1.plot(x, y)
#plt.figure(figsize=(4, 5)
#fig = plt.figure(figsize=(20,30))
for i, image in enumerate(image_list):
    ax = plt.subplot2grid((2,10),(1, i))
    ax.set_axis_off()
    ax.imshow(image, clim=[100, 1600], cmap='gray')
plt.subplots_adjust(wspace=0, hspace=0)
# Out:
# <img src="data:image/png;base64,..." width="640">
