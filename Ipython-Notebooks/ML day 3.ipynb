# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
from scipy.optimize import curve_fit
# Out:
# /home/qsimexpcontrol/.virtualenvs/labrad/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
LT23 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/LifeTime.dir/00023 - LifeTime.csv',delimiter=',')
LT28 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/LifeTime.dir/00028 - LifeTime.csv',delimiter=',')
LT29 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/LifeTime.dir/00029 - LifeTime.csv',delimiter=',')
LT30 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/LifeTime.dir/00030 - LifeTime.csv',delimiter=',')
LT31 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/LifeTime.dir/00031 - LifeTime.csv',delimiter=',')

# %%
print len(LT28[:248,1]), len(LT29[:,1]),len(LT30[:,1]),len(LT31[:,1])

decay_mean = (LT28[:248,1] + LT29[:248,1] + LT30[:248,1] + LT31[:248,1] )/4.0
plt.xlabel('time (s)')
plt.ylabel('Intensity (kcounts/sec)')
plt.plot(LT29[:,0], decay_mean, 'purple')
plt.savefig('/home/qsimexpcontrol/plots/ML_Laser/5JAN2017ionlifetimeML.pdf')
# Out:
# 248 248 251 250
# <img src="data:image/png;base64,...">

# %%
pmt_data = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/PMT Counts.dir/00831 - PMT Counts.csv', delimiter=',')

# %%
times = pmt_data[:,0]
diff_counts = pmt_data[:,3]

# %%
rel_time = times[75638:75779] - times[75638]
data1 = diff_counts[75638:75779]
data2 = diff_counts[75959:76100]
data3 = diff_counts[76280:76421]

# %%
mean = (data1 + data2 + data3)/3.0
plt.title('Ion lifetimes with mode locked laser only')
plt.xlabel('Time (s)')
plt.ylabel('Intensity (kcounts/second)')
plt.plot(rel_time, mean, color = 'purple', lw=2.0, label='6 AUG 2016')
plt.plot(LT23[:,0], LT23[:,1], color='orange', lw=2.0, label = '5 JAN 2017')
plt.legend()
plt.savefig('/home/qsimexpcontrol/plots/ML_Laser/Lifetime_Comparison_single_shot.png')
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.title('Ion lifetimes with mode locked laser only')
plt.xlabel('Time (s)')
plt.ylabel('Intensity (kcounts/second)')
mean = (data1 + data2 + data3)/3.0
plt.plot(rel_time, mean, color = 'purple', lw=2.0, label='6 AUG 2016')
plt.plot(LT29[:,0], decay_mean, color='orange', lw=2.0, label = '5 JAN 2017')
plt.legend()
plt.savefig('/home/qsimexpcontrol/plots/ML_Laser/Lifetime_Comparison_stacked.png')
# Out:
# <img src="data:image/png;base64,...">
