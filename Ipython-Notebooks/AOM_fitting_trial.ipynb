# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook
path = '/home/qsim-rad/LabRAD/Data/InterleavedLineScan.dir/'

# %%
aomScan = np.loadtxt(path + '00493 - InterleavedLinescan.csv',delimiter=',')
aomScan1 = np.loadtxt(path + '00494 - InterleavedLinescan.csv',delimiter=',')
x = np.linspace(- 2*(191.5-152.9),-2*(191.5-237.9),100)
x_cent = aomScan[:,0]
y = aomScan[:,1]
y1 = aomScan1[:,1]
fit = np.polyfit(x,y,20)
fitY = []
for n in range(len(x)):
    fitY.append(np.polyval(fit,x[n]))

max_fit = max(fitY)
norm = []
flat = []
for n in range(len(x_cent)):
    norm.append(max_fit/fitY[n])
    flat.append(y[n]*norm[n])

# %%
plt.plot(x,y)
plt.plot(x, fitY)
plt.plot(x, flat)

print fit
# Out:
# [ -6.24008797e-33   1.19968556e-30   1.60281888e-28  -4.39832776e-26
#   -8.51414472e-25   6.57202702e-22  -1.22211445e-20  -5.25158507e-18
#    2.01151126e-16   2.44693693e-14  -1.25696347e-12  -6.71593941e-11
#    4.16006414e-09   1.02344346e-07  -7.46435947e-06  -7.14960823e-05
#    6.57396410e-03   7.43451182e-03  -2.48652156e+00   1.40807172e+01
#    3.17203009e+03]

# %%
y_max = max(fitY)
c = []
y_new = []
delta_pow = []
for n in range(len(x)):
    c.append(y_max/fitY[n])
    y_new.append(c[n]*y[n])
    delta_pow.append(10*np.log10(norm[n]))
print y_max
# Out:
# 3192.09320967

# %%
#plt.plot(x,y_new)

# %%
#plt.plot(x,delta_pow)
#plt.plot(x_cent, delta_pow)
# Out:
# <img src="data:image/png;base64,..." width="640">
