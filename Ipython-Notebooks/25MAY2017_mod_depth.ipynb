# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
mod_depth = [0.8, 0.77, 0.56, 0.39, 0.3,0.306,0,0.29,0.32,0.55,0.46, 0.47, 0.77, 0.58, 0.73, 1.18]
d = np.linspace(-6,9,16)
a, b, c = np.polyfit(d, mod_depth, 2)
print a, b, c
plt.plot(d, mod_depth)
plt.plot(d, b*d + a*d**2 + c)
# Out:
# 0.0119432773109 -0.017506302521 0.275342436975
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
sp.
