# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %%
data_1 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/PMT_FFT.dir/00324 - PMT_FFT.csv', delimiter = ',')
data_2 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/PMT_FFT.dir/00325 - PMT_FFT.csv', delimiter = ',')

# %%
print np.sum(data_1[:,1])*900
print len(data_1[:,1])
# Out:
# 0.280203767262
# 900

# %%
start = 150
stop = 530
plt.plot(data_1[start:stop,0]/1000, data_1[start:stop,1])
plt.plot(data_2[start:stop,0]/1000, data_2[start:stop,1])
plt.xlabel('Frequency (kHz)')
plt.ylabel("Power (dB)")
#plt.savefig('/home/qsimexpcontrol/plots/phonon_laser/inj_lock.pdf')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
dOmeg = (data_1[:,0][-1] - data_1[:,0][0])/len(data_1[:,0])
print np.sum(dOmeg*np.array(data_1[:,1]))
# Out:
# 0.0103663862867

# %%
data_1 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/PMT_FFT.dir/01193 - PMT_FFT.csv', delimiter = ',')
data_2 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/PMT_FFT.dir/01194mpl.rcParams['axes.linewidth'] = 3. - PMT_FFT.csv', delimiter = ',')

# %%
tRec = 30e-3
mpl.rcParams['axes.linewidth'] = 3.
fig = plt.figure(figsize = (12,8))
ax = plt.axes()
ax.yaxis.set_ticks_position('both')
ax.xaxis.set_ticks_position('both')

ax.tick_params(direction = 'in', width = 2, length = 6)
plt.rc('xtick', labelsize=15)
plt.rc('ytick', labelsize = 15)
font = {'family': 'Times',
        'color':  'k',
        'weight': 'normal',
        'size': 22,
        }
plt.text(544.7, 15.2, 'Injected signal frequency', fontdict=font)
#ax.arrow(545.5, 14.5, 1.3,  -8.2, head_width=0.15, head_length=0.3, fc='orangered', ec='orangered', linewidth=2)
#ax.arrow(546, 14.5, 1.7,  -3.2, head_width=0.15, head_length=0.3, fc='dodgerblue', ec='dodgerblue', linewidth=2)


plt.plot(data_1[70:280,0]/1000, 10*np.log10(1000*tRec*data_1[70:280,1]/50.0) + 67, 'orangered', linewidth = 2.5)
plt.plot(data_2[70:280,0]/1000, 10*np.log10(1000*tRec*data_2[70:280,1]/50.0) + 67, 'dodgerblue', linewidth = 2.5)


#Fancy arrows
ax.annotate("",xy=(546.7, 6.), xycoords='data',xytext=(545.5, 14.5), textcoords='data',\
            arrowprops=dict(arrowstyle="->",connectionstyle="arc3", color = 'orangered', linewidth = 2.5),)

ax.annotate("",xy=(547.8, 12.), xycoords='data',xytext=(546.5, 14.5), textcoords='data',\
            arrowprops=dict(arrowstyle="->",connectionstyle="arc3", color = 'dodgerblue', linewidth = 2.5),)


plt.xlabel('Frequency (kHz)', fontsize = 22)
plt.yticks([0, 5, 10, 15, 20])
#plt.xticks([545, 547, 549, 551])
plt.ylabel("Power Spectral Density (dB/Hz)", fontsize = 22)
plt.ylim([-1.5,21.5])
plt.savefig('/home/qsimexpcontrol/plots/phonon_laser/inj_lock_x_mode.pdf')

# %%
data_1 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/PMT_FFT.dir/00914 - PMT_FFT.csv', delimiter = ',')
data_2 = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/PMT_FFT.dir/00915 - PMT_FFT.csv', delimiter = ',')
