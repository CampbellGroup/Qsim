# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
# %matplotlib notebook

# %%
scan_list_red = []
for data in [372,342,348,339]:
    ss = '/home/qsimexpcontrol/LabRAD/data/velocity_class.dir/00%s - velocity_class.dir/00001 - stacked_images - 00%s - velocity_class.csv' % (data, data)
    scan_list_red.append(np.loadtxt(ss, delimiter=','))

    
scan_list_blue = []
for data in [352,353,354]:
    ss = '/home/qsimexpcontrol/LabRAD/data/velocity_class.dir/00%s - velocity_class.dir/00001 - stacked_images - 00%s - velocity_class.csv' % (data, data)
    scan_list_blue.append(np.loadtxt(ss, delimiter=','))

# %%
# %matplotlib notebook
cm = plt.get_cmap('gist_rainbow_r')
f, ax = plt.subplots(2, sharex=True)
plt.suptitle('Velocity class for nearest tooth red (top) and blue (bottom) detuned', fontsize=12)
plt.xlabel(r'Displacemnt ($\mu$m)')
for i, scan in enumerate(scan_list_red):
    x = 1e6*scan[:,0]
    y = scan[:,1] - background[:,1]
    ax[0].plot(x/1e6,y,color=cm(i/8. + .6))
cm = plt.get_cmap('gist_rainbow_r')
print cm
for i, scan in enumerate(scan_list_blue):
    x = 1e6*scan[:,0]
    y = scan[:,1] - background[:,1]
    ax[1].plot(x/1e6,y, color=cm(i/7.))
plt.savefig('/home/qsimexpcontrol/plots/phonon_laser/2017_OCT_18_velocity_classes.pdf')
# Out:
# <img src="data:image/png;base64,..." width="599.9999869953505">
# ...
# <img src="data:image/png;base64,..." width="599.9999869953505">

# %%
# %matplotlib inline
ss = '/home/qsimexpcontrol/LabRAD/data/velocity_class.dir/00374 - velocity_class.dir/00001 - stacked_images - 00374 - velocity_class.csv'
background = np.loadtxt(ss, delimiter=',')
x = 1e6*background[:,0]
y = background[:,1]
plt.plot(x/1e6,y)

# %%
image_list_red = []
for data in [372,342,348,339]:
    ss = '/home/qsimexpcontrol/LabRAD/data/velocity_class.dir/00%s - velocity_class.dir/00%s - velocity_class.npy' % (data, data)
    image_list_red.append(np.load(ss))

# %%
# %matplotlib inline
for image in image_list_red:
    #image = image[200:300,1:500]
    fig = plt.figure()
    ax = fig.add_subplot(111)
    ax.imshow(image[0].transpose(), cmap='gray')

# %%
image_list_blue = []
for data in [352,353,354]:
    ss = '/home/qsimexpcontrol/LabRAD/data/velocity_class.dir/00%s - velocity_class.dir/00%s - velocity_class.npy' % (data, data)
    image_list_blue.append(np.load(ss))

# %%
# %matplotlib inline
for image in image_list_blue:
    fig = plt.figure()
    ax = fig.add_subplot(1image_list_red = []
for data in [328,342,348,339]:
    ss = '/home/qsimexpcontrol/LabRAD/data/velocity_class.dir/00%s - velocity_class.dir/00%s - velocity_class.npy' % (data, data)
    image_list_red.append(np.load(ss))11)
    ax.imshow(image[0].transpose(), clim = [200,1900], cmap='gray')
