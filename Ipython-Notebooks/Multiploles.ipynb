# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /home/qsimexpcontrol/.virtualenvs/labrad/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
row_1 = np.array([-7.98491456e+04, 9.97290504e+03, -8.34753779e+02,
                 7.83711367e+05, 1.60632984e+06, 2.07110112e+09,
                 -9.21613019e+05, -6.47489511e+06])

row_4 = np.array([9.08217330e+04, -1.26262665e+04, 1.72276248e+03,
                 -8.77337835e+05, -1.19566908e+06, -2.31777025e+09,
                 8.72739472e+05, 7.40424900e+06])

row_3 = np.array([-8.33511849e+04, 1.00807327e+04, -8.42031614e+02,
                 7.83322761e+05, 1.61682392e+06, 2.09390837e+09,
                 -9.31852246e+05, -6.83102436e+06])

row_2 = np.array([7.74809889e+04, -8.14548331e+03, 1.46261072e+03,
                 -7.39129168e+05, -1.03420689e+06, -1.97729719e+09,
                 1.02982636e+06, 6.31653529e+06])

row_5 = np.array([7.83056368e+04, -9.35883102e+03, 7.44032820e+02,
                 -3.96139461e+03, -1.02615220e+06, -1.96518036e+09,
                 8.83825337e+05, 6.13498121e+06])

row_8 = np.array([-7.50714648e+04, 7.79852359e+03, -1.41418832e+03,
                 -1.51076112e+04, 1.52982245e+06, 1.91561317e+09,
                 -7.22981923e+05, -6.11870080e+06])

row_7 = np.array([7.54130105e+04, -9.32179831e+03, 7.41447591e+02,
                 -3.88766024e+03, -1.02233674e+06, -1.95737952e+09,
                 8.80325442e+05, 6.39450469e+06])

row_6 = np.array([-8.01616368e+04, 1.10981675e+04, -1.51302236e+03,
                 3.74643059e+04, 1.59176500e+06, 2.04552764e+09,
                 -1.05562593e+06, -6.53377462e+06])

# %%
U = np.array([row_1, row_2, row_3, row_4, row_5, row_6, row_7, row_8])

# %%
M = np.linalg.inv(U)
M
# Out:
# array([[  1.92817953e-04,  -3.48638943e-08,  -1.92939245e-04,
#          -2.36990058e-09,   1.90290909e-04,  -2.88652748e-07,
#          -1.93889400e-04,  -2.04396577e-07],
#        [  1.52664070e-06,   1.94342125e-04,   1.54243210e-06,
#          -1.49422744e-04,   2.03747021e-07,   1.94129531e-04,
#           3.52631632e-07,  -1.90254319e-04],
#        [  3.52749793e-04,   3.53800526e-04,   3.52859848e-04,
#           3.26279248e-04,  -3.56309228e-04,  -3.54099744e-04,
#          -3.54030764e-04,  -3.56278199e-04],
#        [  3.45330920e-07,  -3.45261000e-07,   3.45641997e-07,
#          -2.43882512e-07,   3.36143934e-07,  -3.45822683e-07,
#           3.44796668e-07,  -3.36202487e-07],
#        [  4.73355977e-07,   4.73452108e-07,   4.73392799e-07,
#           4.54486263e-07,   4.72385802e-07,   4.73402045e-07,
#           4.73600230e-07,   4.72393256e-07],
#        [  1.30388667e-08,  -2.48735353e-10,  -1.32848036e-08,
#          -1.10681448e-10,   1.14265792e-09,  -2.11329601e-09,
#          -2.61432628e-09,   1.31294660e-09],
#        [  6.80353891e-09,   1.75994136e-06,   6.91708992e-09,
#          -1.57624077e-06,   9.75889593e-10,  -1.76087290e-06,
#           1.01248524e-09,   1.77687355e-06],
#        [  1.75353633e-06,  -2.47506337e-10,  -1.75483502e-06,
#           3.15934147e-12,  -1.77720193e-06,  -1.53230769e-09,
#           1.76009959e-06,  -1.03071206e-09]])

# %%
r = 500e-5
M_no_units = np.array([M[0, 0:]/r, M[1, 0:]/r, M[2, 0:]/r, M[3, 0:]/r**2,
                      M[4, 0:]/r**2, M[5, 0:]/r**2, M[6, 0:]/r**2, M[7, 0:]/r**2])
plt.matshow(M_no_units)
# Out:
# <img src="data:image/png;base64,...">

# %%
row_1 = [-1., 0., 1., 0., -1., 0., 1., 0.]
row_2 = [0., 1., 0., -1., 0., 1., 0., -1.]
row_3 = [-1., -1., -1., -1., 1., 1., 1. ,1.]
row_4 = [1., 1., 1., 1., 1., 1., 1., 1.]
row_5 = [1., -1., 1., -1., 1., -1., 1., -1.]
row_6 = [1., 0., -1., 0., -1., 0., 1., 0.]
row_7 = [0., -1., 0., 1., 0., 1., 0., -1.]
row_8 = [1/3., -1.0, 5/3., -1.0, -1/3., 1., -5/3., 1.]

Usimple = np.array([row_1, row_2, row_3, row_4, row_5, row_6, row_7, row_8])
plt.matshow(Usimple)
# Out:
# <img src="data:image/png;base64,...">

# %%
f = np.linspace(1e3, 1e6)
fp = f*np.sqrt(1 + 1.77e13/(2*np.pi*f)**2)
plt.plot(f, fp - f)
# Out:
# <img src="data:image/png;base64,...">
