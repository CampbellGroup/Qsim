# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
center_pll_dds = 12.6428039223e9
center_pll_magiq = 12.64260186e9
DDS_source_wide = np.loadtxt('/home/qsimexpcontrol/plots/DDS_Noise/Trace_0011_data.csv',delimiter=',')
DDS_source_narrow = np.loadtxt('/home/qsimexpcontrol/plots/DDS_Noise/Trace_0012_data.csv',delimiter=',')
magiQ_source_narrow = np.loadtxt('/home/qsimexpcontrol/plots/DDS_Noise/Trace_0018_data.csv',delimiter=',')
magiQ_source_wide = np.loadtxt('/home/qsimexpcontrol/plots/DDS_Noise/Trace_0017_data.csv',delimiter=',')

# %%
plt.figure()
plt.subplot(121)
plt.plot((DDS_source_wide[:,0]-center_pll_dds)/1000., DDS_source_wide[:,1], 'purple', label='source=DDS')
plt.plot((magiQ_source_wide[:,0]-center_pll_magiq)/1000., magiQ_source_wide[:,1], 'darkorange', alpha=0.8, label='source=MagiQ')
plt.xlabel('Detuning from 12.642 GHz (kHz)')
plt.ylabel('Power (dBm)')
plt.legend()

plt.subplot(122)
plt.plot((DDS_source_narrow[:,0] - center_pll_dds)/1000., DDS_source_narrow[:,1], 'purple', label='source=DDS')
plt.plot((magiQ_source_narrow[:,0]-center_pll_magiq)/1000., magiQ_source_narrow[:,1], 'darkorange', alpha=0.8, label='source=MagiQ')
plt.xlabel('Detuning from 12.642 GHz (kHz)')
plt.ylabel('Power (dBm)')
plt.suptitle('PLL output DDS vs MagiQ', fontsize=16)
plt.legend()
#plt.savefig("/home/qsimexpcontrol/plots/DAC_Noise/before_afterextfilter.pdf")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1089">

# %%
center_dds = 93.65039935*1e6
center_magiq = 93.648903136*1e6
DDS_only_wide = np.loadtxt('/home/qsimexpcontrol/plots/DDS_Noise/Trace_0019_data.csv',delimiter=',')
DDS_only_narrow = np.loadtxt('/home/qsimexpcontrol/plots/DDS_Noise/Trace_0020_data.csv',delimiter=',')
DDS_only_high_power_wide = np.loadtxt('/home/qsimexpcontrol/plots/DDS_Noise/Trace_0013_data.csv',delimiter=',')
DDS_only_high_power_narrow = np.loadtxt('/home/qsimexpcontrol/plots/DDS_Noise/Trace_0014_data.csv',delimiter=',')
magiQ_only_wide = np.loadtxt('/home/qsimexpcontrol/plots/DDS_Noise/Trace_0016_data.csv',delimiter=',')
magiQ_only_narrow = np.loadtxt('/home/qsimexpcontrol/plots/DDS_Noise/Trace_0015_data.csv',delimiter=',')

# %%
plt.figure()
plt.subplot(121)
plt.plot((DDS_only_wide[:,0]-center_dds)/1000., DDS_only_wide[:,1], 'blue', label='DDS low')
plt.plot((DDS_only_high_power_wide[:,0]-center_dds)/1000., DDS_only_high_power_wide[:,1], 'purple', label='DDS high')
plt.plot((magiQ_only_wide[:,0]-center_magiq)/1000., magiQ_only_wide[:,1], 'darkorange', alpha=0.8, label='magiQ')
plt.xlabel('Detuning from 93.65 MHz (kHz)')
plt.ylabel('Power (dbm)')
plt.legend(loc=1)
plt.subplot(122)
plt.plot((DDS_only_narrow[:,0]-center_dds)/1000., DDS_only_narrow[:,1], 'blue', label='DDS low')
plt.plot((DDS_only_high_power_narrow[:,0]-center_dds)/1000., DDS_only_high_power_narrow[:,1], 'purple', label='DDS high')
plt.plot((magiQ_only_narrow[:,0]-center_magiq)/1000., magiQ_only_narrow[:,1], 'darkorange', alpha=0.8, label='magiQ')
plt.xlabel('Detuning from 93.65 MHz (kHz)')
plt.ylabel('Power (dbm)')
plt.suptitle('PLL input DDS vs MagiQ', fontsize=16)
plt.legend(loc=1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1023">

# %%
plt.figure()
plt.plot((DDS_only_narrow[:,0]-center_dds)/1000., DDS_only_narrow[:,1], 'purple')
plt.plot((DDS_only_high_power_narrow[:,0]-center_dds)/1000., DDS_only_high_power_narrow[:,1])
plt.plot((magiQ_only_narrow[:,0]-center_magiq)/1000., magiQ_only_narrow[:,1])
plt.xlabel('Frequency(kHz)')
plt.ylabel('Power (dbm)')
#plt.savefig("/home/qsimexpcontrol/plots/DAC_Noise/before_25/135afterextfilter.pdf")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
