# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/PMT Counts.dir/01226 - PMT Counts.csv',delimiter=',')

# %%
plt.plot(data[:,0], data[:,1])
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
plt.plot(data[151403:151820,0], data[151403:151820,1], label = 'hopping')
plt.plot(data[151820:152100,0], data[151820:152100,1], label = 'not hopping')

tmpx = data[151403:151820,0]
tmpy = data[151403:151820,1]

f = open("/home/qsimexpcontrol/plots/6_ion_metastable/23JUN2017hopping_pmt.csv", "w")

for i in xrange(len(tmpx)):
    f.write("{} {}\n".format(tmpx[i], tmpy[i]))

f.close()
plt.title('6 ion crystal from stable to metastable')
plt.savefig('/home/qsimexpcontrol/plots/6_ion_metastable/23JUN2017hopping_pmt.pdf')
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
