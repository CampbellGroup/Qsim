# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt('/home/qsimexpcontrol/LabRAD/data/PMT Counts.dir/01234 - PMT Counts.csv',delimiter=',')

# %%
plt.plot(np.array(data[29150:30680,0])/10.0, data[29150:30680,1])
plt.title('6 ion crystal hopping')
plt.xlabel('time, (s)')
plt.ylabel('Fluorescence (kcts/sec)')
plt.savefig('/home/qsimexpcontrol/plots/6_ion_metastable/26JUN2017hopping_pmt.pdf')
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
tmpx = data[29150:30680,0]
tmpy = data[29150:30680,1]

f = open("/home/qsimexpcontrol/plots/6_ion_metastable/26JUN2017hopping_pmt.csv", "w")

for i in xrange(len(tmpx)):
    f.write("{} {}\n".format(tmpx[i], tmpy[i]))
